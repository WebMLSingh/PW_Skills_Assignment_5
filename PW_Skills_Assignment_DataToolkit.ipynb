# %%
#### Run This Cell First
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %% [markdown]
# 1. Demonstrate three different methods for creating identical 2D arrays in NumPy. Provide the code for each method and the final output after each method

# %%
# Method 1: Using np.array() with a nested list
array_method_1 = np.array([[1, 2], [3, 4]])

# Method 2: Using np.full() to fill a 2D array with specific values
array_method_2 = np.full((2, 2), [[1, 2], [3, 4]])

# Method 3: Using np.reshape() to reshape a flat array into 2D
array_method_3 = np.array([1, 2, 3, 4]).reshape(2, 2)

array_method_1, array_method_2, array_method_3
# Out:
# (array([[1, 2],
#         [3, 4]]),
#  array([[1, 2],
#         [3, 4]]),
#  array([[1, 2],
#         [3, 4]]))

# %% [markdown]
# 2. Using the Numpy function, generate an array of 100 evenly spaced numbers between 1 and 10 and Reshape that 1D array into a 2D array

# %%
# Generating an array of 100 evenly spaced numbers between 1 and 10
evenly_spaced_array = np.linspace(1, 10, 100)

# Reshaping the 1D array into a 2D array (10 rows and 10 columns)
reshaped_array = evenly_spaced_array.reshape(10, 10)

reshaped_array
# Out:
# array([[ 1.        ,  1.09090909,  1.18181818,  1.27272727,  1.36363636,
#          1.45454545,  1.54545455,  1.63636364,  1.72727273,  1.81818182],
#        [ 1.90909091,  2.        ,  2.09090909,  2.18181818,  2.27272727,
#          2.36363636,  2.45454545,  2.54545455,  2.63636364,  2.72727273],
#        [ 2.81818182,  2.90909091,  3.        ,  3.09090909,  3.18181818,
#          3.27272727,  3.36363636,  3.45454545,  3.54545455,  3.63636364],
#        [ 3.72727273,  3.81818182,  3.90909091,  4.        ,  4.09090909,
#          4.18181818,  4.27272727,  4.36363636,  4.45454545,  4.54545455],
#        [ 4.63636364,  4.72727273,  4.81818182,  4.90909091,  5.        ,
#          5.09090909,  5.18181818,  5.27272727,  5.36363636,  5.45454545],
#        [ 5.54545455,  5.63636364,  5.72727273,  5.81818182,  5.90909091,
#          6.        ,  6.09090909,  6.18181818,  6.27272727,  6.36363636],
#        [ 6.45454545,  6.54545455,  6.63636364,  6.72727273,  6.81818182,
# ...

# %% [markdown]
# 3. Explain the following terms
#
#
# *   The difference in np.array, np.asarray and np.asanyarray
# *   The difference between Deep copy and shallow cop

# %%
# Attached in PDF https://drive.google.com/file/d/1i9-dkOnlOfcazlnQjPsq6Q2_XbEI9vXm/view?usp=sharing

# %% [markdown]
# 4. Generate a 3x3 array with random floating-point numbers between 5 and 20. Then, round each number in the array to 2 decimal places

# %%
# Generating a 3x3 array with random floating-point numbers between 5 and 20
random_array = np.random.uniform(5, 20, (3, 3))

# Rounding each number in the array to 2 decimal places
rounded_array = np.round(random_array, 2)

rounded_array
# Out:
# array([[ 9.19, 17.56, 16.02],
#        [11.7 , 11.22, 13.68],
#        [ 6.52, 15.59, 11.3 ]])

# %% [markdown]
# 5. Create a NumPy array with random integers between 1 and 10 of shape (5, 6). After creating the array perform the following operations:
# *  a)Extract all even integers from array.
# *  b)Extract all odd integers from array

# %%
# Creating a NumPy array with random integers between 1 and 10 of shape (5, 6)
random_int_array = np.random.randint(1, 11, (5, 6))

# Extracting all even integers from the array
even_integers = random_int_array[random_int_array % 2 == 0]

# Extracting all odd integers from the array
odd_integers = random_int_array[random_int_array % 2 != 0]

random_int_array, even_integers, odd_integers
# Out:
# (array([[ 6,  3,  2,  9,  9,  2],
#         [ 6,  6,  8,  7, 10,  3],
#         [ 4, 10,  9,  3, 10,  3],
#         [10,  1,  8,  2,  3,  6],
#         [ 1,  5,  3,  4,  5,  6]]),
#  array([ 6,  2,  2,  6,  6,  8, 10,  4, 10, 10, 10,  8,  2,  6,  4,  6]),
#  array([3, 9, 9, 7, 3, 9, 3, 3, 1, 3, 1, 5, 3, 5]))

# %% [markdown]
# 6. Create a 3D NumPy array of shape (3, 3, 3) containing random integers between 1 and 10. Perform the following operations:
# *   a) Find the indices of the maximum values along each depth level (third axis).
# *   b) Perform element-wise multiplication of between both array

# %%
# Create a 3D array of shape (3, 3, 3) with random integers between 1 and 10
array_3d = np.random.randint(1, 11, (3, 3, 3))

# a) Find the indices of the maximum values along each depth level (third axis)
max_indices = np.argmax(array_3d, axis=2)

# b) Perform element-wise multiplication of the array by itself
multiplied_array = array_3d * array_3d  # This performs element-wise multiplication

# Print results
print("3D Array:\n", array_3d)
print("\nIndices of Maximum Values Along Each Depth Level:\n", max_indices)
print("\nElement-wise Multiplied Array:\n", multiplied_array)
# Out:
# 3D Array:
#  [[[ 3  7  6]
#   [10  4  6]
#   [ 5  4  9]]
#
#  [[ 8  2  9]
#   [ 9  5  3]
#   [ 6  8  9]]
#
#  [[ 1  2  6]
#   [ 6  2  5]
#   [ 1 10  5]]]
#
# Indices of Maximum Values Along Each Depth Level:
#  [[1 0 2]
#  [2 0 2]
#  [2 0 1]]
#
# Element-wise Multiplied Array:
#  [[[  9  49  36]
#   [100  16  36]
#   [ 25  16  81]]
#
#  [[ 64   4  81]
#   [ 81  25   9]
#   [ 36  64  81]]
#
#  [[  1   4  36]
#   [ 36   4  25]
#   [  1 100  25]]]

# %% [markdown]
# 7. Clean and transform the 'Phone' column in the sample dataset to remove non-numeric characters and convert it to a numeric data type. Also display the table attributes and data types of each column

# %%
# Load the dataset
file_path = '/People Data.csv'
data = pd.read_csv(file_path)

# Clean the 'Phone' column by removing non-numeric characters
data['Phone'] = data['Phone'].str.replace(r'\D', '', regex=True)

# Convert 'Phone' column to a numeric data type
data['Phone'] = pd.to_numeric(data['Phone'])

# Display table attributes and data types of each column
data_info = data.dtypes

data.head(), data_info
# Out:
# (   Index          User Id First Name Last Name  Gender  \
#  0      1  8717bbf45cCDbEe     Shelia   Mahoney    Male
#  1      2  3d5AD30A4cD38ed         Jo    Rivers  Female
#  2      3  810Ce0F276Badec     Sheryl    Lowery  Female
#  3      4  BF2a889C00f0cE1    Whitney    Hooper    Male
#  4      5  9afFEafAe1CBBB9    Lindsey      Rice  Female
#
#                             Email         Phone Date of birth  \
#  0            pwarner@example.org  8.571398e+09    27-01-2014
#  1  fergusonkatherine@example.net           NaN    26-07-1931
#  2            fhoward@example.org  5.997821e+09    25-11-2013
#  3          zjohnston@example.com           NaN    17-11-2012
#  4               elin@example.net  3.904172e+13    15-04-1923
#
#                    Job Title  Salary
#  0         Probation officer   90000
#  1                    Dancer   80000
#  2                      Copy   50000
#  3  Counselling psychologist   65000
#  4       Biomedical engineer  100000  ,
# ...

# %% [markdown]
# 8. Perform the following tasks using people dataset:
# *   a) Read the 'data.csv' file using pandas, skipping the first 50 rows.
# *   b) Only read the columns: 'Last Name', ‘Gender’,’Email’,‘Phone’ and ‘Salary’ from the file.
# *   c) Display the first 10 rows of the filtered dataset.
# *   d) Extract the ‘Salary’' column as a Series and display its last 5 values

# %%
# a) Read the 'People Data.csv' file using pandas, skipping the first 50 rows
file_path = '/People Data.csv'
data = pd.read_csv(file_path, skiprows=range(1, 50))

# b) Only read the columns: 'Last Name', 'Gender', 'Email', 'Phone', and 'Salary'
filtered_data = data[['Last Name', 'Gender', 'Email', 'Phone', 'Salary']]

# c) Display the first 10 rows of the filtered dataset
print(filtered_data.head(10))

# d) Extract the 'Salary' column as a Series and display its last 5 values
salary_series = filtered_data['Salary']
print(salary_series.tail(5))
# Out:
#   Last Name  Gender                         Email                   Phone  \
# 0    Mercer  Female  douglascontreras@example.net    +1-326-669-0118x4341
# 1    Zavala    Male          pamela64@example.net  001-859-448-9935x54536
# 2     Carey  Female     dianashepherd@example.net    001-274-739-8470x814
# 3     Hobbs  Female     ingramtiffany@example.org        241.179.9509x498
# 4    Reilly    Male    carriecrawford@example.org       207.797.8345x6177
# 5    Conrad    Male    fuentesclaudia@example.net    001-599-042-7428x143
# 6      Cole    Male        kaneaudrey@example.org            663-280-5834
# 7   Donovan    Male     rebekahsantos@example.net                     NaN
# 8    Little  Female           craig28@example.com       125.219.3673x0076
# 9    Dawson  Female    connercourtney@example.net      650-748-3069x64529
#
#    Salary
# 0   70000
# 1   80000
# 2   70000
# 3   60000
# 4  100000
# 5   50000
# 6   85000
# 7   65000
# 8   60000
# 9   60000
# 946     90000
# ...

# %% [markdown]
# 9. Filter and select rows from the People_Dataset, where the “Last Name' column contains the name 'Duke', 'Gender' column contains the word Female and 'Salary' should be less than 85000

# %%
file_path = '/People Data.csv'
data = pd.read_csv(file_path)
# Filtering the dataset where 'Last Name' contains 'Duke', 'Gender' is 'Female', and 'Salary' is less than 85000
filtered_rows = data[(data['Last Name'] == 'Duke') & (data['Gender'] == 'Female') & (data['Salary'] < 85000)]

# Display the filtered rows
filtered_rows
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 45      46  99A502C175C4EBd     Olivia      Duke  Female
# 210    211  DF17975CC0a0373    Katrina      Duke  Female
# 457    458  dcE1B7DE83c1076      Traci      Duke  Female
# 729    730  c9b482D7aa3e682     Lonnie      Duke  Female
#
#                         Email                   Phone Date of birth  \
# 45        diana26@example.net  001-366-475-8607x04350    13-10-1934
# 210       robin78@example.com            740.434.0212    21-09-1935
# 457  perryhoffman@example.org     +1-903-596-0995x489    11-02-1997
# 729   kevinkramer@example.net            982.692.6257    12-05-2015
#
#            Job Title  Salary
# 45           Dentist   60000
# 210  Producer, radio   50000
# 457        Herbalist   50000
# 729     Nurse, adult   70000

# %% [markdown]
# 10. Create a 7*5 Dataframe in Pandas using a series generated from 35 random integers between 1 to 6?

# %%
# Generating a series of 35 random integers between 1 and 6
random_series = np.random.randint(1, 7, 35)

# Reshaping the series into a 7x5 DataFrame
df = pd.DataFrame(random_series.reshape(7, 5), columns=['A', 'B', 'C', 'D', 'E'])

# Display the DataFrame
print(df)
# Out:
#    A  B  C  D  E
# 0  4  5  6  5  3
# 1  4  2  4  4  1
# 2  4  2  2  3  3
# 3  4  5  4  6  2
# 4  3  5  3  6  6
# 5  6  6  5  3  5
# 6  5  4  2  6  4

# %% [markdown]
# 11. Create two different Series, each of length 50, with the following criteria:
# *  a) The first Series should contain random numbers ranging from 10 to 50.
# * b) The second Series should contain random numbers ranging from 100 to 1000.
# * c) Create a DataFrame by joining these Series by column, and, change the names of the columns to 'col1', 'col2', etc

# %%
# a) The first Series should contain random numbers ranging from 10 to 50
series1 = pd.Series(np.random.randint(10, 51, 50))

# b) The second Series should contain random numbers ranging from 100 to 1000
series2 = pd.Series(np.random.randint(100, 1001, 50))

# c) Create a DataFrame by joining these Series by column
df = pd.DataFrame({
    'col1': series1,
    'col2': series2
})

# Display the DataFrame
print(df)
# Out:
#     col1  col2
# 0     21   116
# 1     18   616
# 2     33   938
# 3     40   187
# 4     16   900
# 5     49   788
# 6     23   778
# 7     23   783
# 8     18   707
# 9     46   404
# 10    38   577
# 11    34   159
# 12    23   131
# 13    44   499
# 14    48   978
# 15    34   834
# 16    42   221
# 17    27   845
# 18    42   561
# 19    16   151
# 20    21   550
# 21    43   930
# 22    40   961
# 23    14   369
# 24    27   494
# 25    12   987
# 26    31   402
# 27    14   228
# 28    10   492
# 29    28   660
# 30    37   422
# 31    21   497
# 32    31   210
# 33    20   221
# 34    31   225
# 35    11   894
# 36    48   711
# 37    19   634
# 38    38   741
# 39    42   619
# 40    27   793
# 41    36   375
# 42    39   916
# 43    42   226
# 44    20   496
# 45    19   996
# 46    11   720
# 47    20   927
# 48    10   985
# 49    31   281

# %% [markdown]
# 12. Perform the following operations using people data set:
# * a) Delete the 'Email', 'Phone', and 'Date of birth' columns from the dataset.
# *  b) Delete the rows containing any missing values.
# * d) Print the final output also

# %%
file_path = '/People Data.csv'
data = pd.read_csv(file_path)

# a) Delete the 'Email', 'Phone', and 'Date of birth' columns from the dataset
data_dropped_columns = data.drop(columns=['Email', 'Phone', 'Date of birth'])

# b) Delete the rows containing any missing values
cleaned_data = data_dropped_columns.dropna()

# d) Print the final output
cleaned_data
# Out:
#      Index          User Id First Name Last Name  Gender  \
# 0        1  8717bbf45cCDbEe     Shelia   Mahoney    Male
# 1        2  3d5AD30A4cD38ed         Jo    Rivers  Female
# 2        3  810Ce0F276Badec     Sheryl    Lowery  Female
# 3        4  BF2a889C00f0cE1    Whitney    Hooper    Male
# 4        5  9afFEafAe1CBBB9    Lindsey      Rice  Female
# ..     ...              ...        ...       ...     ...
# 995    996  fedF4c7Fd9e7cFa       Kurt    Bryant  Female
# 996    997  ECddaFEDdEc4FAB      Donna     Barry  Female
# 997    998  2adde51d8B8979E      Cathy  Mckinney  Female
# 998    999  Fb2FE369D1E171A   Jermaine    Phelps    Male
# 999   1000  8b756f6231DDC6e        Lee      Tran  Female
#
#                            Job Title  Salary
# 0                  Probation officer   90000
# 1                             Dancer   80000
# 2                               Copy   50000
# 3           Counselling psychologist   65000
# 4                Biomedical engineer  100000
# ...

# %% [markdown]
# 13. Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the following tasks using Matplotlib and NumPy:
# * a) Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'.
# * b) Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.
# * c) Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'.
# * d) Label the x-axis as 'X-axis' and the y-axis as 'Y-axis'.
# * e) Set the title of the plot as 'Advanced Scatter Plot of Random Values'.
# * f) Display a legend for the scatter plot, the horizontal line, and the vertical line.

# %%
# Create two NumPy arrays x and y with 100 random float values between 0 and 1
x = np.random.rand(100)
y = np.random.rand(100)

# Create scatter plot
plt.scatter(x, y, color='red', marker='o', label='Scatter')

# Add a horizontal line at y = 0.5
plt.axhline(y=0.5, color='blue', linestyle='--', label='y = 0.5')

# Add a vertical line at x = 0.5
plt.axvline(x=0.5, color='green', linestyle=':', label='x = 0.5')

# Label the axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Set title of the plot
plt.title('Advanced Scatter Plot of Random Values')

# Display a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# 14. Create a time-series dataset in a Pandas DataFrame with columns: 'Date', 'Temperature', 'Humidity' and Perform the following tasks using Matplotlib:
# * a) Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes (left y-axis for 'Temperature' and right y-axis for 'Humidity').
# * b) Label the x-axis as 'Date'.
# * c) Set the title of the plot as 'Temperature and Humidity Over Time'.

# %%
# Generate a time-series dataset
dates = pd.date_range(start='2023-01-01', periods=100, freq='D')
temperature = np.random.uniform(low=15, high=35, size=100)  # Random temperature values between 15 and 35 degrees
humidity = np.random.uniform(low=40, high=90, size=100)      # Random humidity values between 40% and 90%

# Create a DataFrame
data = {'Date': dates, 'Temperature': temperature, 'Humidity': humidity}
df = pd.DataFrame(data)

# Create the plot
fig, ax1 = plt.subplots(figsize=(10, 6))

# Plot Temperature on the left y-axis
ax1.plot(df['Date'], df['Temperature'], 'r-', label='Temperature')
ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature (°C)', color='r')
ax1.tick_params('y', colors='r')

# Create a second y-axis for Humidity
ax2 = ax1.twinx()
ax2.plot(df['Date'], df['Humidity'], 'b-', label='Humidity')
ax2.set_ylabel('Humidity (%)', color='b')
ax2.tick_params('y', colors='b')

# Set title and format x-axis for dates
plt.title('Temperature and Humidity Over Time')
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# 15. Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following tasks using Matplotlib:
# * a) Plot a histogram of the data with 30 bins.
# * b) Overlay a line plot representing the normal distribution's probability density function (PDF).
# * c) Label the x-axis as 'Value' and the y-axis as 'Frequency/Probability'.
# * d) Set the title of the plot as 'Histogram with PDF Overlay'

# %%
# Generate 1000 samples from a normal distribution
data = np.random.randn(1000)

# Create the histogram
count, bins, ignored = plt.hist(data, bins=30, density=True, alpha=0.6, color='g', label='Histogram')

# Calculate and plot the PDF (Probability Density Function)
mu, sigma = 0, 1  # Mean and standard deviation for standard normal distribution
pdf = (1 / (sigma * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((bins - mu) / sigma) ** 2)
plt.plot(bins, pdf, 'r-', lw=2, label='PDF')

# Label the axes
plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

# Set the title of the plot
plt.title('Histogram with PDF Overlay')

# Display legend
plt.legend()

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# 17. Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the origin (quadrants), add a legend, label the axes, and set the title as 'Quadrant-wise Scatter Plot'.

# %%
import seaborn as sns

# Create two random arrays
x = np.random.randn(100)
y = np.random.randn(100)

# Determine quadrants
quadrants = []
for i in range(len(x)):
    if x[i] >= 0 and y[i] >= 0:
        quadrants.append('Quadrant I')
    elif x[i] < 0 and y[i] >= 0:
        quadrants.append('Quadrant II')
    elif x[i] < 0 and y[i] < 0:
        quadrants.append('Quadrant III')
    else:
        quadrants.append('Quadrant IV')

# Create a DataFrame for Seaborn
df = pd.DataFrame({'x': x, 'y': y, 'Quadrant': quadrants})

# Create scatter plot with coloring based on quadrants
plt.figure(figsize=(8, 6))
sns.scatterplot(x='x', y='y', hue='Quadrant', data=df, palette='deep')

# Label axes
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

# Set title
plt.title('Quadrant-wise Scatter Plot')

# Add a legend
plt.legend(title='Quadrants')

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# 18. With Bokeh, plot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'Sine Wave Function'

# %%
from bokeh.plotting import figure, show
# Generate data for the sine wave
x = np.linspace(0, 4 * np.pi, 100)
y = np.sin(x)

# Create a Bokeh plot
p = figure(title="Sine Wave Function", x_axis_label='X-axis', y_axis_label='Y-axis')

# Plot the sine wave
p.line(x, y, line_width=2)

# Add grid lines
p.xgrid.visible = True
p.ygrid.visible = True

# Show the plot
show(p)
# Out:
#   <div id="fa71e6f9-1cc4-414c-a9ae-20950be92628" data-root-id="p1221" style="display: contents;"></div>

# %% [markdown]
# 19. Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their values, add hover tooltips to display exact values, label the axes, and set the title as 'Random Categorical Bar Chart'

# %%
from bokeh.io import show
from bokeh.plotting import figure
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.transform import factor_cmap
import random
import string
import pandas as pd

# Step 1: Generate random categorical data
categories = [''.join(random.choices(string.ascii_uppercase, k=5)) for _ in range(10)]
values = [random.randint(10, 100) for _ in range(10)]

# Create a DataFrame to hold the data
data = pd.DataFrame({
    'Category': categories,
    'Value': values
})

# Step 2: Create a ColumnDataSource
source = ColumnDataSource(data)

# Step 3: Create a figure for the bar chart
p = figure(x_range=categories,
           title="Random Categorical Bar Chart",
           toolbar_location=None,
           tools="")

# Step 4: Create the bar chart with color mapping
p.vbar(x='Category',
       top='Value',
       width=0.9,
       source=source,
       line_color='white',
       fill_color=factor_cmap('Category', palette="Viridis256", factors=categories))

# Step 5: Add hover tooltips to display the exact values
hover = HoverTool()
hover.tooltips = [("Category", "@Category"), ("Value", "@Value")]
p.add_tools(hover)

# Step 6: Label the axes and rotate x-axis labels for readability
p.xgrid.grid_line_color = None
p.y_range.start = 0
p.xaxis.axis_label = "Category"
p.yaxis.axis_label = "Value"
p.xaxis.major_label_orientation = 1.2

# Step 7: Display the bar chart
show(p)
# Out:
#   <div id="bf5ceeef-3fa9-4c55-93f5-a1a455aa46c3" data-root-id="p1497" style="display: contents;"></div>

# %% [markdown]
# 20. Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as 'Simple Line Plot'

# %%
import plotly.graph_objects as go
import numpy as np

# Generate random data
np.random.seed(0)  # For reproducibility
x_values = np.arange(10)  # X values (0 to 9)
y_values = np.random.rand(10) * 100  # Random Y values scaled to 0-100

# Create a line plot
fig = go.Figure()

# Add a trace for the line
fig.add_trace(go.Scatter(x=x_values, y=y_values, mode='lines+markers', name='Random Data'))

# Update layout with title and axis labels
fig.update_layout(
    title='Simple Line Plot',
    xaxis_title='X Axis',
    yaxis_title='Y Axis'
)

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# 21. Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set the title as 'Interactive Pie Chart'

# %%
import plotly.graph_objects as go
import numpy as np

# Generate random data
np.random.seed(0)  # For reproducibility
labels = ['A', 'B', 'C', 'D', 'E']  # Pie chart labels
values = np.random.randint(1, 100, size=len(labels))  # Random values

# Create a pie chart
fig = go.Figure(data=[go.Pie(labels=labels, values=values,
                               textinfo='label+percent',
                               hoverinfo='label+percent')])

# Update layout with title
fig.update_layout(title='Interactive Pie Chart')

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
